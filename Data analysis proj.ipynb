# %% [markdown]
# # GDSC - Team 5
#
# ### COVID-19 country_wise_latest Data

# %%
#importing libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
dataset = pd.read_csv("C:\\Users\\hp\\Downloads\\dataset.csv")

# %%
dataset
# Out:
#          Country/Region  Confirmed  Deaths  Recovered  Active  New cases  \
# 0           Afghanistan      36263    1269      25198    9796        106
# 1               Albania       4880     144       2745    1991        117
# 2               Algeria      27973    1163      18837    7973        616
# 3               Andorra        907      52        803      52         10
# 4                Angola        950      41        242     667         18
# ..                  ...        ...     ...        ...     ...        ...
# 182  West Bank and Gaza      10621      78       3752    6791        152
# 183      Western Sahara         10       1          8       1          0
# 184               Yemen       1691     483        833     375         10
# 185              Zambia       4552     140       2815    1597         71
# 186            Zimbabwe       2704      36        542    2126        192
#
#      New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# ...

# %%
dataset.head()
# Out:
#   Country/Region  Confirmed  Deaths  Recovered  Active  New cases  New deaths  \
# 0    Afghanistan      36263    1269      25198    9796        106          10
# 1        Albania       4880     144       2745    1991        117           6
# 2        Algeria      27973    1163      18837    7973        616           8
# 3        Andorra        907      52        803      52         10           0
# 4         Angola        950      41        242     667         18           1
#
#    New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 0             18                3.50                  69.49
# 1             63                2.95                  56.25
# 2            749                4.16                  67.34
# 3              0                5.73                  88.53
# 4              0                4.32                  25.47
#
#    Deaths / 100 Recovered  Confirmed last week  1 week change  \
# 0                    5.04                35526            737
# ...

# %%
#Prints information of all columns 
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 187 entries, 0 to 186
# Data columns (total 15 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Country/Region          187 non-null    object
#  1   Confirmed               187 non-null    int64
#  2   Deaths                  187 non-null    int64
#  3   Recovered               187 non-null    int64
#  4   Active                  187 non-null    int64
#  5   New cases               187 non-null    int64
#  6   New deaths              187 non-null    int64
#  7   New recovered           187 non-null    int64
#  8   Deaths / 100 Cases      187 non-null    float64
#  9   Recovered / 100 Cases   187 non-null    float64
#  10  Deaths / 100 Recovered  187 non-null    float64
#  11  Confirmed last week     187 non-null    int64
#  12  1 week change           187 non-null    int64
#  13  1 week % increase       187 non-null    float64
# ...

# %%
#missing values
dataset.isna().sum()
# Out:
# Country/Region            0
# Confirmed                 0
# Deaths                    0
# Recovered                 0
# Active                    0
# New cases                 0
# New deaths                0
# New recovered             0
# Deaths / 100 Cases        0
# Recovered / 100 Cases     0
# Deaths / 100 Recovered    0
# Confirmed last week       0
# 1 week change             0
# 1 week % increase         0
# WHO Region                0
# dtype: int64

# %%
#Generate descriptive statistics of Dataset columns.
dataset.groupby("WHO Region").describe()
# Out:
#                       Confirmed                                                \
#                           count           mean            std    min      25%
# WHO Region
# Africa                     48.0   15066.812500   65087.434387   10.0   910.00
# Americas                   35.0  252551.028571  817100.096342   17.0   265.00
# Eastern Mediterranean      22.0   67761.090909   93399.654809  674.0  3367.50
# Europe                     56.0   58920.053571  127226.689411   12.0  2157.50
# South-East Asia            10.0  183529.700000  461327.177069   24.0   963.75
# Western Pacific            16.0   18276.750000   29427.554873   20.0   204.75
#
#                                                     Deaths               ...  \
#                            50%       75%        max  count         mean  ...
# WHO Region                                                               ...
# Africa                  2129.5   7088.50   452529.0   48.0   254.645833  ...
# ...

# %%
dataset.groupby("Country/Region").describe()
# Out:
# E:\anaconda\lib\site-packages\numpy\lib\function_base.py:3961: RuntimeWarning: invalid value encountered in subtract
#   diff_b_a = subtract(b, a)
#                    Confirmed                                                   \
#                        count     mean std      min      25%      50%      75%
# Country/Region
# Afghanistan              1.0  36263.0 NaN  36263.0  36263.0  36263.0  36263.0
# Albania                  1.0   4880.0 NaN   4880.0   4880.0   4880.0   4880.0
# Algeria                  1.0  27973.0 NaN  27973.0  27973.0  27973.0  27973.0
# Andorra                  1.0    907.0 NaN    907.0    907.0    907.0    907.0
# Angola                   1.0    950.0 NaN    950.0    950.0    950.0    950.0
# ...                      ...      ...  ..      ...      ...      ...      ...
# West Bank and Gaza       1.0  10621.0 NaN  10621.0  10621.0  10621.0  10621.0
# Western Sahara           1.0     10.0 NaN     10.0     10.0     10.0     10.0
# ...

# %%
dataset.groupby("WHO Region").max()
# Out:
#                       Country/Region  Confirmed  Deaths  Recovered   Active  \
# WHO Region
# Africa                      Zimbabwe     452529    7067     274925   170537
# Americas                   Venezuela    4290259  148011    1846641  2816444
# Eastern Mediterranean          Yemen     293606   15912     255144    52992
# Europe                    Uzbekistan     816680   45844     602249   254427
# South-East Asia          Timor-Leste    1480073   33408     951166   495499
# Western Pacific              Vietnam      86783    4656      78869    53649
#
#                        New cases  New deaths  New recovered  \
# WHO Region
# Africa                      7096         298           9848
# Americas                   56336        1076          33728
# Eastern Mediterranean       2553         212           3592
# Europe                      5607          85           3077
# South-East Asia            44457         637          33598
# ...

# %%
dataset.groupby("WHO Region").min()
# Out:
#                             Country/Region  Confirmed  Deaths  Recovered  \
# WHO Region
# Africa                             Algeria         10       0          0
# Americas               Antigua and Barbuda         17       0          0
# Eastern Mediterranean          Afghanistan        674      11          0
# Europe                             Albania         12       0          0
# South-East Asia                 Bangladesh         24       0          0
# Western Pacific                  Australia         20       0         11
#
#                        Active  New cases  New deaths  New recovered  \
# WHO Region
# Africa                      1          0           0              0
# Americas                    0          0           0              0
# Eastern Mediterranean      24          3           0              0
# Europe                      0          0           0              0
# South-East Asia            13          0           0              0
# ...

# %%
#sorted by Ascending
dataset.sort_values(["Confirmed"] , axis=0)
# Out:
#             Country/Region  Confirmed  Deaths  Recovered   Active  New cases  \
# 183         Western Sahara         10       1          8        1          0
# 75                Holy See         12       0         12        0          0
# 68               Greenland         14       0         13        1          1
# 140  Saint Kitts and Nevis         17       0         15        2          0
# 49                Dominica         18       0         18        0          0
# ..                     ...        ...     ...        ...      ...        ...
# 154           South Africa     452529    7067     274925   170537       7096
# 138                 Russia     816680   13334     602249   201097       5607
# 79                   India    1480073   33408     951166   495499      44457
# 23                  Brazil    2442375   87618    1846641   508116      23284
# 173                     US    4290259  148011    1325804  2816444      56336
#
# ...

# %%
#sorted by Ascending
dataset.sort_values(["Deaths"] , axis=0)
# Out:
#      Country/Region  Confirmed  Deaths  Recovered   Active  New cases  \
# 59             Fiji         27       0         18        9          0
# 75         Holy See         12       0         12        0          0
# 69          Grenada         23       0         23        0          0
# 94             Laos         20       0         19        1          0
# 68        Greenland         14       0         13        1          1
# ..              ...        ...     ...        ...      ...        ...
# 85            Italy     246286   35112     198593    12581        168
# 111          Mexico     395489   44022     303810    47657       4973
# 177  United Kingdom     301708   45844       1437   254427        688
# 23           Brazil    2442375   87618    1846641   508116      23284
# 173              US    4290259  148011    1325804  2816444      56336
#
#      New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# ...

# %%
#sorted by Ascending
dataset.sort_values(["Recovered"] , axis=0)
# Out:
#     Country/Region  Confirmed  Deaths  Recovered   Active  New cases  \
# 32          Canada     116458    8944          0   107514        682
# 163          Syria        674      40          0      634         24
# 147         Serbia      24141     543          0    23598        411
# 161         Sweden      79395    5700          0    73695        398
# 117     Mozambique       1701      11          0     1690         32
# ..             ...        ...     ...        ...      ...        ...
# 35           Chile     347923    9187     319954    18782       2133
# 138         Russia     816680   13334     602249   201097       5607
# 79           India    1480073   33408     951166   495499      44457
# 173             US    4290259  148011    1325804  2816444      56336
# 23          Brazil    2442375   87618    1846641   508116      23284
#
#      New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# ...

# %%
#sorted by Ascending
dataset.sort_values(["Active"] , axis=0)
# Out:
#      Country/Region  Confirmed  Deaths  Recovered   Active  New cases  \
# 49         Dominica         18       0         18        0          0
# 143      San Marino        699      42        657        0          0
# 69          Grenada         23       0         23        0          0
# 75         Holy See         12       0         12        0          0
# 24           Brunei        141       3        138        0          0
# ..              ...        ...     ...        ...      ...        ...
# 138          Russia     816680   13334     602249   201097       5607
# 177  United Kingdom     301708   45844       1437   254427        688
# 79            India    1480073   33408     951166   495499      44457
# 23           Brazil    2442375   87618    1846641   508116      23284
# 173              US    4290259  148011    1325804  2816444      56336
#
#      New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# ...

# %%
#sorted by Ascending
dataset.sort_values(["New cases"] , axis=0)
# Out:
#                        Country/Region  Confirmed  Deaths  Recovered   Active  \
# 59                               Fiji         27       0         18        9
# 24                             Brunei        141       3        138        0
# 142  Saint Vincent and the Grenadines         52       0         39       13
# 143                        San Marino        699      42        657        0
# 166                          Tanzania        509      21        183      305
# ..                                ...        ...     ...        ...      ...
# 132                              Peru     389717   18418     272547    98752
# 37                           Colombia     257101    8777     131161   117163
# 23                             Brazil    2442375   87618    1846641   508116
# 79                              India    1480073   33408     951166   495499
# 173                                US    4290259  148011    1325804  2816444
#
# ...

# %%
dataset.columns
# Out:
# Index(['Country/Region', 'Confirmed', 'Deaths', 'Recovered', 'Active',
#        'New cases', 'New deaths', 'New recovered', 'Deaths / 100 Cases',
#        'Recovered / 100 Cases', 'Deaths / 100 Recovered',
#        'Confirmed last week', '1 week change', '1 week % increase',
#        'WHO Region'],
#       dtype='object')

# %% [markdown]
# ### Data Visualization

# %%
dataset['Recovered / 100 Cases'].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
#discovering outliers
dataset['Deaths / 100 Cases'].plot.box()
# Out:
# <AxesSubplot:>

# %%
#handling outliers
dataset.loc[dataset["Deaths / 100 Cases"]> 8 ,"Deaths / 100 Cases" ] = np.mean(dataset["Deaths / 100 Cases"])

# %%
dataset['Deaths / 100 Cases'].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
#new dataset
dataset2 = dataset [['Confirmed' , 'Deaths' , 'Recovered' , 'Active']]

# %%
sns.barplot (data = dataset2 )
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(dataset2.corr())
# Out:
# <AxesSubplot:>

# %%
#dataset 3
dataset3 = dataset [['New cases' , 'New deaths' , 'New recovered'] ]

# %%
sns.barplot(data = dataset3)
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(dataset3.corr())
# Out:
# <AxesSubplot:>

# %%
us = dataset.sort_values(["Confirmed"] , axis=0).iloc[-1]
us
# Out:
# Country/Region                  US
# Confirmed                  4290259
# Deaths                      148011
# Recovered                  1325804
# Active                     2816444
# New cases                    56336
# New deaths                    1076
# New recovered                27941
# Deaths / 100 Cases            3.45
# Recovered / 100 Cases         30.9
# Deaths / 100 Recovered       11.16
# Confirmed last week        3834677
# 1 week change               455582
# 1 week % increase            11.88
# WHO Region                Americas
# Name: 173, dtype: object

# %%
us_visual = {'US' : { 'Confirmed' : 4290259 ,
'Deaths' : 148011 ,
'Recovered' : 1325804 ,
'Active' : 2816444 ,
'New cases' : 56336 ,
'New deaths' : 1076 ,
'New recovered' : 27941 ,
'Deaths / 100 Cases' : 3.45 ,
'Recovered / 100 Cases' : 30.9 ,
'Deaths / 100 Recovered' : 11.16 , 
'Confirmed last week' : 3834677 ,
'1 week change' : 455582 ,
'1 week % increase' : 11.88 
} }

# %%
d = pd.DataFrame([(i,j,us_visual[i][j]) for i in us_visual.keys() for j in us_visual[i].keys()], columns=["country", "cases", "ratio"])

# %%
fig = plt.figure(figsize=(15,5))
ax = sns.barplot(x='cases' , y='ratio' , hue="country" , data=d)
plt.xticks(rotation=45)
plt.show()

# %%
#least country in confirmed cases
wstern_sahara = dataset.sort_values(["Confirmed"] , axis=0).iloc[0]
wstern_sahara
# Out:
# Country/Region            Western Sahara
# Confirmed                             10
# Deaths                                 1
# Recovered                              8
# Active                                 1
# New cases                              0
# New deaths                             0
# New recovered                          0
# Deaths / 100 Cases              3.019519
# Recovered / 100 Cases               80.0
# Deaths / 100 Recovered              12.5
# Confirmed last week                   10
# 1 week change                          0
# 1 week % increase                    0.0
# WHO Region                        Africa
# Name: 183, dtype: object

# %%
ws_visual = {'wstern_sahara' : { 'Confirmed' : 10 ,
'Deaths' : 1 ,
'Recovered' : 8 ,
'Active' : 1 ,
'New cases' : 0 ,
'New deaths' :  0 ,
'New recovered' : 0 ,
'Deaths / 100 Cases' : 10 ,
'Recovered / 100 Cases' : 80 ,
'Deaths / 100 Recovered' : 12.5 ,
'Confirmed last week' : 10 ,
'1 week change' : 0 ,
'1 week % increase' : 0    
} }
    
s = pd.DataFrame([(i,j,ws_visual[i][j]) for i in ws_visual.keys() for j in ws_visual[i].keys()], columns=["country", "cases", "ratio"])

# %%
fig = plt.figure(figsize=(15,5))
ax = sns.barplot(x='cases' , y='ratio' , hue="country" , data=s)
plt.xticks(rotation=45)
plt.show()
